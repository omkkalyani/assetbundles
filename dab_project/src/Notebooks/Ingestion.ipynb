# %%
dbutils.widgets.text('catalog', 'assetbundles')

# %%
catalog_name = dbutils.widgets.get('catalog')

# %%
# %sql
select * from assetbundles.information_schema.columns

# %%
df=spark.sql(f'select * from {catalog_name}.information_schema.columns')
display(df)
